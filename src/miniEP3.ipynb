# %% [markdown]
# # EP1 - Paralelizando o Cálculo do Conjunto de Mandelbrot com Pthreads e OpenMP
#
# ## Integrantes
#
# | Nome | NUSP |
# |------|------|
# | Iggor Francis Numata Matthews | 10262572 |
# | João Gabriel Loureiro de Lima Lembo | 10737178 |
# | Otávio Ho Aragoni | 9793798 |
# | Victor Pereira Lima| 10737028 |

# %%
] up

# %% [markdown]
# Verifique o status dos pacotes, e se há algum problema, com o comando:

# %%
] st

# %%
; bash run_measurements.sh
# Out:
# make: Nothing to be done for 'all'.
# + MEASUREMENTS=2
# + ITERATIONS=5
# + INITIAL_SIZE=128
# + THREADS=1
# + NAMES=('mandelbrot_seq' 'mandelbrot_pth')
# + make
# + mkdir results
# mkdir: cannot create directory ‘results’: File exists
# + for NAME in ${NAMES[@]}
# + mkdir results/mandelbrot_seq
# mkdir: cannot create directory ‘results/mandelbrot_seq’: File exists
# + '[' mandelbrot_seq = mandelbrot_seq ']'
# + end=1
# + (( t=1 ))
# + (( t<=1 ))
# + SIZE=128
# + (( i=1 ))
# + (( i<=5 ))
# + echo 'Info 1 128 2'
# + echo 'Info 1 128 2'
# + echo 'Info 1 128 2'
# + echo 'Info 1 128 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_seq -2.5 1.5 -2.0 2.0 128 1
# + ./mandelbrot_seq -0.8 -0.7 0.05 0.15 128 1
# + ./mandelbrot_seq 0.175 0.375 -0.1 0.1 128 1
# + ./mandelbrot_seq -0.188 -0.012 0.554 0.754 128 1
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_seq -2.5 1.5 -2.0 2.0 128 1
# + ./mandelbrot_seq -0.8 -0.7 0.05 0.15 128 1
# + ./mandelbrot_seq 0.175 0.375 -0.1 0.1 128 1
# + ./mandelbrot_seq -0.188 -0.012 0.554 0.754 128 1
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=256
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 1 256 2'
# + echo 'Info 1 256 2'
# + echo 'Info 1 256 2'
# + echo 'Info 1 256 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_seq -2.5 1.5 -2.0 2.0 256 1
# + ./mandelbrot_seq -0.8 -0.7 0.05 0.15 256 1
# + ./mandelbrot_seq 0.175 0.375 -0.1 0.1 256 1
# + ./mandelbrot_seq -0.188 -0.012 0.554 0.754 256 1
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_seq -2.5 1.5 -2.0 2.0 256 1
# + ./mandelbrot_seq -0.8 -0.7 0.05 0.15 256 1
# + ./mandelbrot_seq 0.175 0.375 -0.1 0.1 256 1
# + ./mandelbrot_seq -0.188 -0.012 0.554 0.754 256 1
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=512
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 1 512 2'
# + echo 'Info 1 512 2'
# + echo 'Info 1 512 2'
# + echo 'Info 1 512 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_seq -2.5 1.5 -2.0 2.0 512 1
# + ./mandelbrot_seq -0.8 -0.7 0.05 0.15 512 1
# + ./mandelbrot_seq 0.175 0.375 -0.1 0.1 512 1
# + ./mandelbrot_seq -0.188 -0.012 0.554 0.754 512 1
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_seq -2.5 1.5 -2.0 2.0 512 1
# + ./mandelbrot_seq -0.8 -0.7 0.05 0.15 512 1
# + ./mandelbrot_seq 0.175 0.375 -0.1 0.1 512 1
# + ./mandelbrot_seq -0.188 -0.012 0.554 0.754 512 1
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=1024
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 1 1024 2'
# + echo 'Info 1 1024 2'
# + echo 'Info 1 1024 2'
# + echo 'Info 1 1024 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_seq -2.5 1.5 -2.0 2.0 1024 1
# + ./mandelbrot_seq -0.8 -0.7 0.05 0.15 1024 1
# + ./mandelbrot_seq 0.175 0.375 -0.1 0.1 1024 1
# + ./mandelbrot_seq -0.188 -0.012 0.554 0.754 1024 1
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_seq -2.5 1.5 -2.0 2.0 1024 1
# + ./mandelbrot_seq -0.8 -0.7 0.05 0.15 1024 1
# + ./mandelbrot_seq 0.175 0.375 -0.1 0.1 1024 1
# + ./mandelbrot_seq -0.188 -0.012 0.554 0.754 1024 1
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=2048
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 1 2048 2'
# + echo 'Info 1 2048 2'
# + echo 'Info 1 2048 2'
# + echo 'Info 1 2048 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_seq -2.5 1.5 -2.0 2.0 2048 1
# + ./mandelbrot_seq -0.8 -0.7 0.05 0.15 2048 1
# + ./mandelbrot_seq 0.175 0.375 -0.1 0.1 2048 1
# + ./mandelbrot_seq -0.188 -0.012 0.554 0.754 2048 1
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_seq -2.5 1.5 -2.0 2.0 2048 1
# + ./mandelbrot_seq -0.8 -0.7 0.05 0.15 2048 1
# + ./mandelbrot_seq 0.175 0.375 -0.1 0.1 2048 1
# + ./mandelbrot_seq -0.188 -0.012 0.554 0.754 2048 1
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=4096
# + (( i++ ))
# + (( i<=5 ))
# + THREADS=2
# + (( t++ ))
# + (( t<=1 ))
# + SIZE=128
# + mv elephant.log full.log seahorse.log triple_spiral.log results/mandelbrot_seq
# + rm output.ppm
# + for NAME in ${NAMES[@]}
# + mkdir results/mandelbrot_pth
# mkdir: cannot create directory ‘results/mandelbrot_pth’: File exists
# + '[' mandelbrot_pth = mandelbrot_seq ']'
# + end=6
# + (( t=1 ))
# + (( t<=6 ))
# + SIZE=128
# + (( i=1 ))
# + (( i<=5 ))
# + echo 'Info 2 128 2'
# + echo 'Info 2 128 2'
# + echo 'Info 2 128 2'
# + echo 'Info 2 128 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 2
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 2
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 2
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 2
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 2
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 2
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 2
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 2
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=256
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 2 256 2'
# + echo 'Info 2 256 2'
# + echo 'Info 2 256 2'
# + echo 'Info 2 256 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 2
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 2
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 2
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 2
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 2
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 2
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 2
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 2
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=512
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 2 512 2'
# + echo 'Info 2 512 2'
# + echo 'Info 2 512 2'
# + echo 'Info 2 512 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 2
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 2
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 2
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 2
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 2
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 2
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 2
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 2
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=1024
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 2 1024 2'
# + echo 'Info 2 1024 2'
# + echo 'Info 2 1024 2'
# + echo 'Info 2 1024 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 2
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 2
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 2
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 2
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 2
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 2
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 2
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 2
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=2048
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 2 2048 2'
# + echo 'Info 2 2048 2'
# + echo 'Info 2 2048 2'
# + echo 'Info 2 2048 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 2
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 2
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 2
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 2
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 2
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 2
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 2
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 2
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=4096
# + (( i++ ))
# + (( i<=5 ))
# + THREADS=4
# + (( t++ ))
# + (( t<=6 ))
# + SIZE=128
# + (( i=1 ))
# + (( i<=5 ))
# + echo 'Info 4 128 2'
# + echo 'Info 4 128 2'
# + echo 'Info 4 128 2'
# + echo 'Info 4 128 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 4
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 4
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 4
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 4
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 4
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 4
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 4
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 4
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=256
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 4 256 2'
# + echo 'Info 4 256 2'
# + echo 'Info 4 256 2'
# + echo 'Info 4 256 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 4
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 4
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 4
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 4
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 4
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 4
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 4
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 4
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=512
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 4 512 2'
# + echo 'Info 4 512 2'
# + echo 'Info 4 512 2'
# + echo 'Info 4 512 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 4
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 4
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 4
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 4
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 4
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 4
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 4
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 4
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=1024
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 4 1024 2'
# + echo 'Info 4 1024 2'
# + echo 'Info 4 1024 2'
# + echo 'Info 4 1024 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 4
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 4
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 4
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 4
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 4
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 4
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 4
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 4
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=2048
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 4 2048 2'
# + echo 'Info 4 2048 2'
# + echo 'Info 4 2048 2'
# + echo 'Info 4 2048 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 4
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 4
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 4
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 4
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 4
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 4
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 4
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 4
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=4096
# + (( i++ ))
# + (( i<=5 ))
# + THREADS=8
# + (( t++ ))
# + (( t<=6 ))
# + SIZE=128
# + (( i=1 ))
# + (( i<=5 ))
# + echo 'Info 8 128 2'
# + echo 'Info 8 128 2'
# + echo 'Info 8 128 2'
# + echo 'Info 8 128 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 8
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 8
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 8
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 8
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 8
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 8
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 8
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 8
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=256
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 8 256 2'
# + echo 'Info 8 256 2'
# + echo 'Info 8 256 2'
# + echo 'Info 8 256 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 8
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 8
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 8
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 8
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 8
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 8
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 8
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 8
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=512
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 8 512 2'
# + echo 'Info 8 512 2'
# + echo 'Info 8 512 2'
# + echo 'Info 8 512 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 8
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 8
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 8
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 8
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 8
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 8
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 8
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 8
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=1024
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 8 1024 2'
# + echo 'Info 8 1024 2'
# + echo 'Info 8 1024 2'
# + echo 'Info 8 1024 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 8
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 8
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 8
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 8
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 8
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 8
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 8
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 8
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=2048
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 8 2048 2'
# + echo 'Info 8 2048 2'
# + echo 'Info 8 2048 2'
# + echo 'Info 8 2048 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 8
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 8
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 8
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 8
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 8
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 8
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 8
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 8
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=4096
# + (( i++ ))
# + (( i<=5 ))
# + THREADS=16
# + (( t++ ))
# + (( t<=6 ))
# + SIZE=128
# + (( i=1 ))
# + (( i<=5 ))
# + echo 'Info 16 128 2'
# + echo 'Info 16 128 2'
# + echo 'Info 16 128 2'
# + echo 'Info 16 128 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 16
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 16
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 16
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 16
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 16
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 16
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 16
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 16
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=256
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 16 256 2'
# + echo 'Info 16 256 2'
# + echo 'Info 16 256 2'
# + echo 'Info 16 256 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 16
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 16
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 16
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 16
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 16
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 16
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 16
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 16
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=512
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 16 512 2'
# + echo 'Info 16 512 2'
# + echo 'Info 16 512 2'
# + echo 'Info 16 512 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 16
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 16
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 16
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 16
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 16
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 16
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 16
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 16
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=1024
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 16 1024 2'
# + echo 'Info 16 1024 2'
# + echo 'Info 16 1024 2'
# + echo 'Info 16 1024 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 16
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 16
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 16
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 16
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 16
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 16
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 16
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 16
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=2048
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 16 2048 2'
# + echo 'Info 16 2048 2'
# + echo 'Info 16 2048 2'
# + echo 'Info 16 2048 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 16
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 16
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 16
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 16
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 16
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 16
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 16
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 16
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=4096
# + (( i++ ))
# + (( i<=5 ))
# + THREADS=32
# + (( t++ ))
# + (( t<=6 ))
# + SIZE=128
# + (( i=1 ))
# + (( i<=5 ))
# + echo 'Info 32 128 2'
# + echo 'Info 32 128 2'
# + echo 'Info 32 128 2'
# + echo 'Info 32 128 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 32
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 32
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 32
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 32
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 32
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 32
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 32
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 32
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=256
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 32 256 2'
# + echo 'Info 32 256 2'
# + echo 'Info 32 256 2'
# + echo 'Info 32 256 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 32
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 32
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 32
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 32
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 32
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 32
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 32
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 32
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=512
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 32 512 2'
# + echo 'Info 32 512 2'
# + echo 'Info 32 512 2'
# + echo 'Info 32 512 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 32
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 32
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 32
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 32
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 32
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 32
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 32
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 32
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=1024
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 32 1024 2'
# + echo 'Info 32 1024 2'
# + echo 'Info 32 1024 2'
# + echo 'Info 32 1024 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 32
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 32
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 32
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 32
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 32
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 32
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 32
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 32
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=2048
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 32 2048 2'
# + echo 'Info 32 2048 2'
# + echo 'Info 32 2048 2'
# + echo 'Info 32 2048 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 32
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 32
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 32
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 32
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 32
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 32
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 32
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 32
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=4096
# + (( i++ ))
# + (( i<=5 ))
# + THREADS=64
# + (( t++ ))
# + (( t<=6 ))
# + SIZE=128
# + (( i=1 ))
# + (( i<=5 ))
# + echo 'Info 64 128 2'
# + echo 'Info 64 128 2'
# + echo 'Info 64 128 2'
# + echo 'Info 64 128 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 64
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 64
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 64
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 64
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 128 64
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 128 64
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 128 64
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 128 64
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=256
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 64 256 2'
# + echo 'Info 64 256 2'
# + echo 'Info 64 256 2'
# + echo 'Info 64 256 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 64
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 64
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 64
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 64
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 256 64
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 256 64
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 256 64
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 256 64
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=512
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 64 512 2'
# + echo 'Info 64 512 2'
# + echo 'Info 64 512 2'
# + echo 'Info 64 512 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 64
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 64
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 64
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 64
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 512 64
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 512 64
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 512 64
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 512 64
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=1024
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 64 1024 2'
# + echo 'Info 64 1024 2'
# + echo 'Info 64 1024 2'
# + echo 'Info 64 1024 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 64
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 64
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 64
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 64
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 1024 64
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 1024 64
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 1024 64
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 1024 64
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=2048
# + (( i++ ))
# + (( i<=5 ))
# + echo 'Info 64 2048 2'
# + echo 'Info 64 2048 2'
# + echo 'Info 64 2048 2'
# + echo 'Info 64 2048 2'
# + (( j=1 ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 64
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 64
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 64
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 64
# + (( j++ ))
# + (( j<=2 ))
# + ./mandelbrot_pth -2.5 1.5 -2.0 2.0 2048 64
# + ./mandelbrot_pth -0.8 -0.7 0.05 0.15 2048 64
# + ./mandelbrot_pth 0.175 0.375 -0.1 0.1 2048 64
# + ./mandelbrot_pth -0.188 -0.012 0.554 0.754 2048 64
# + (( j++ ))
# + (( j<=2 ))
# + SIZE=4096
# + (( i++ ))
# + (( i<=5 ))
# + THREADS=128
# + (( t++ ))
# + (( t<=6 ))
# + SIZE=128
# + mv elephant.log full.log seahorse.log triple_spiral.log results/mandelbrot_pth
# + rm output.ppm

# %% [markdown]
# # READ LOG TO DATAFRAME HERE

# %%
import Base.read
import Pkg
Pkg.add("DataFrames")
Pkg.add("Query")
Pkg.add("StatsPlots")
Pkg.add("Distributions")
Pkg.add("Statistics")
Pkg.add("PGFPlotsX")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  99.9 %0.0 %Fetching: [======>                                  ]  12.6 %>                      ]  42.8 %                ]  57.6 %5 %>            ]  68.9 %Fetching: [================================>        ]  78.3 %   ]  90.5 %Fetching: [=======================================> ]  97.2 %Fetching: [========================================>]  97.6 % Resolving package versions...
#  Installed Compat ───────────── v3.10.0
#  Installed Parsers ──────────── v1.0.4
#  Installed OrderedCollections ─ v1.2.0
#  Installed DataStructures ───── v0.17.16
#  Installed CategoricalArrays ── v0.8.1
#  Installed DataFrames ───────── v0.21.0
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [a93c6f00] + DataFrames v0.21.0
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#   [b99e7846] ↑ BinaryProvider v0.5.8 ⇒ v0.5.9
#   [324d7699] + CategoricalArrays v0.8.1
#   [34da2185] + Compat v3.10.0
#   [9a962f9c] + DataAPI v1.3.0
#   [a93c6f00] + DataFrames v0.21.0
#   [864edb3b] + DataStructures v0.17.16
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [41ab1584] + InvertedIndices v1.0.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [e1d29d7a] + Missings v0.4.3
#   [bac558e1] + OrderedCollections v1.2.0
#   [69de0a69] ↑ Parsers v1.0.1 ⇒ v1.0.4
#   [2dfb63ee] + PooledArrays v0.5.3
#   [189a3867] + Reexport v0.2.0
#   [a2af1166] + SortingAlgorithms v0.3.1
#   [3783bdb8] + TableTraits v1.0.0
#   [bd369af6] + Tables v1.0.4
#   [8bb1440f] + DelimitedFiles
#   [9fa8497b] + Future
#   [1a1011a3] + SharedArrays
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [1a8c2f83] + Query v0.12.2
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#   [e7dc6d0d] + DataValues v0.4.13
#   [1c8ee90f] + IterableTables v1.0.0
#   [1914dd2f] + MacroTools v0.5.5
#   [1a8c2f83] + Query v0.12.2
#   [2aef5ad7] + QueryOperators v0.9.1
#   [ae029012] + Requires v1.0.1
#   [5e66a065] + TableShowUtils v0.2.5
#   [382cd787] + TableTraitsUtils v1.0.1
#  Resolving package versions...
#  Installed StatsPlots ────── v0.14.6
#  Installed FillArrays ────── v0.8.9
#  Installed PlotUtils ─────── v1.0.3
#  Installed GeometryTypes ─── v0.8.3
#  Installed Contour ───────── v0.5.3
#  Installed StaticArrays ──── v0.12.3
#  Installed ColorTypes ────── v0.10.3
#  Installed UnPack ────────── v1.0.1
#  Installed Parameters ────── v0.12.1
#  Installed Plots ─────────── v1.3.2
#  Installed Optim ─────────── v0.21.0
#  Installed GR ────────────── v0.49.1
#  Installed RecipesPipeline ─ v0.1.9
#  Installed StatsFuns ─────── v0.9.5
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [f3b207a7] + StatsPlots v0.14.6
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#   [621f4979] + AbstractFFTs v0.5.0
#   [7d9fca2a] + Arpack v0.3.2
#   [4fba245c] + ArrayInterface v2.2.0
#   [13072b0f] + AxisAlgorithms v1.0.0
#   [9e28174c] + BinDeps v1.0.1
#   [49dc2e85] + Calculus v0.5.1
#   [aaaa29a8] + Clustering v0.14.0
#   [35d6a980] + ColorSchemes v3.9.0
#   [3da002f7] + ColorTypes v0.10.3
#   [5ae59095] + Colors v0.12.0
#   [bbf7d656] + CommonSubexpressions v0.2.0
#   [d38c429a] + Contour v0.5.3
#   [01453d9d] + DiffEqDiffTools v1.6.0
#   [163ba53b] + DiffResults v1.0.2
#   [b552c78f] + DiffRules v1.0.1
#   [b4f34e82] + Distances v0.8.2
#   [31c24e10] + Distributions v0.23.2
#   [c87230d0] + FFMPEG v0.2.4
#   [7a1cc6ca] + FFTW v1.1.0
#   [1a297f60] + FillArrays v0.8.9
#   [53c48c17] + FixedPointNumbers v0.8.0
#   [f6369f11] + ForwardDiff v0.10.10
#   [28b8d3ca] + GR v0.49.1
#   [4d00f742] + GeometryTypes v0.8.3
#   [a98d9a8b] + Interpolations v0.12.9
#   [5ab0869b] + KernelDensity v0.5.1
#   [d3d80556] + LineSearches v7.0.1
#   [442fdcdd] + Measures v0.3.1
#   [6f286f6a] + MultivariateStats v0.7.0
#   [d41bc354] + NLSolversBase v7.5.0
#   [77ba4419] + NaNMath v0.3.3
#   [b8a86587] + NearestNeighbors v0.4.4
#   [510215fc] + Observables v0.3.1
#   [6fe1bfb0] + OffsetArrays v1.0.4
#   [429524aa] + Optim v0.21.0
#   [90014a1f] + PDMats v0.9.12
#   [d96e819e] + Parameters v0.12.1
#   [ccf2f8ad] + PlotThemes v2.0.0
#   [995b91a9] + PlotUtils v1.0.3
#   [91a5bcdd] + Plots v1.3.2
#   [85a6dd25] + PositiveFactorizations v0.2.3
#   [1fd47b50] + QuadGK v2.3.1
#   [c84ed2f1] + Ratios v0.4.0
#   [3cdcf5f2] + RecipesBase v1.0.1
#   [01d81517] + RecipesPipeline v0.1.9
#   [79098fc4] + Rmath v0.6.0
#   [992d4aef] + Showoff v0.3.1
#   [276daf66] + SpecialFunctions v0.8.0
#   [90137ffa] + StaticArrays v0.12.3
#   [2913bbd2] + StatsBase v0.33.0
#   [4c63d2b9] + StatsFuns v0.9.5
#   [f3b207a7] + StatsPlots v0.14.6
#   [ab02a1b2] + TableOperations v0.2.1
#   [30578b45] + URIParser v0.4.1
#   [3a884ed6] + UnPack v1.0.1
#   [cc8bc4a8] + Widgets v0.6.2
#   [efce3f68] + WoodburyMatrices v0.5.2
#   [4607b0f0] + SuiteSparse
#   Building GR ───→ `~/.julia/packages/GR/cRdXQ/deps/build.log`
#   Building Plots → `~/.julia/packages/Plots/FYxdA/deps/build.log`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [31c24e10] + Distributions v0.23.2
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [10745b16] + Statistics
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [8314cec4] + PGFPlotsX v1.2.6
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#   [dce04be8] + ArgCheck v2.0.0
#   [3f0dd361] + DefaultApplication v1.0.0
#   [ffbed154] + DocStringExtensions v0.8.1
#   [8314cec4] + PGFPlotsX v1.2.6

# %%
using DataFrames, Query, StatsPlots, Statistics

function readingSeqFiles(figure)
    resultsPath = "$(@__DIR__)/results"
    
    results = DataFrame(size = Int[],
        io_time = Float64[],
        allocation_time = Float64[],
        full_time = Float64[])  
    
    filepath = "$(resultsPath)/mandelbrot_seq/$(figure).log"
    open(filepath) do f
        while !eof(f)
            line = readline(f)
            lineArray = split(line, ' ')
            if lineArray[1] == "Info" 
                imageSize = parse(Int64, lineArray[3])
                measurements = parse(Int64, lineArray[4])
                for i in 1:measurements
                    line = split(readline(f), ' ')
                    append!(results, DataFrame(size = imageSize,
                                               io_time = parse(Float64, line[1]),
                                               allocation_time = parse(Float64, line[2]),
                                               full_time = parse(Float64, line[3])))
                end
            end
        end
    end
    return results
end
# Out:
# ┌ Info: Recompiling stale cache file /home/vitinho/.julia/compiled/v1.0/DataFrames/AR9oZ.ji for DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# └ @ Base loading.jl:1190
# ┌ Info: Recompiling stale cache file /home/vitinho/.julia/compiled/v1.0/Query/wGX7b.ji for Query [1a8c2f83-1ff3-5112-b086-8aa67b057ba1]
# └ @ Base loading.jl:1190
# ┌ Info: Recompiling stale cache file /home/vitinho/.julia/compiled/v1.0/StatsPlots/SiylL.ji for StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1190
# readingSeqFiles (generic function with 1 method)

# %%
function parse_seq_results(results)
    parsed_results = results |>
                    @groupby(_.size) |>
                    @map({size = key(_),
                          mean_io_estimate = mean(_.io_time),
                          ci_io_estimate = 1.96 * std(_.io_time),
                          mean_alloc_estimate = mean(_.allocation_time),
                          ci_alloc_estimate = 1.96 * std(_.allocation_time),
                          mean_full_estimate = mean(_.full_time),
                          ci_full_estimate = 1.96 * std(_.full_time)}) |>
                    DataFrame
    
    return parsed_results
end
# Out:
# parse_seq_results (generic function with 1 method)

# %%
pgfplotsx()

function plot_seq_results(x, y, title, yerror = [], min_size = 0, max_size = 16)      
        p = scatter(x,
            y,
            title = title,
            xaxis = :log2,
            xlabel = "Tamanho da Entrada",
            xticks = [2 ^ x for x in min_size:max_size],
            yerror = yerror,
            alpha = 0.6,
            legend = :topright)
    
    return p
end
# Out:
# ┌ Info: Recompiling stale cache file /home/vitinho/.julia/compiled/v1.0/PGFPlotsX/ckKEQ.ji for PGFPlotsX [8314cec4-20b6-5062-9cdb-752b83310925]
# └ @ Base loading.jl:1190
# ┌ Info: Recompiling stale cache file /home/vitinho/.julia/compiled/v1.0/Contour/ZECEP.ji for Contour [d38c429a-6771-53c6-b99e-75d170b6e991]
# └ @ Base loading.jl:1190
# plot_seq_results (generic function with 4 methods)

# %%
function readingThreadFiles(figure, size, thread_type)
    resultsPath = "$(@__DIR__)/results"
    
    results = DataFrame(size = Int[],
                        threads = Int[],
                        full_time = Float64[])  
    
    filepath = "$(resultsPath)/mandelbrot_$(thread_type)/$(figure).log"
    open(filepath) do f
        while !eof(f)
            line = readline(f)
            lineArray = split(line, ' ')
            if lineArray[1] == "Info"
                if parse(Int64, lineArray[3]) == size
                    imageSize = size
                    threads = parse(Int64, lineArray[2])
                    measurements = parse(Int64, lineArray[4])
                    for i in 1:measurements
                        line = split(readline(f), ' ')
                        append!(results, DataFrame(size = imageSize,
                                                   threads = threads,
                                                   full_time = parse(Float64, line[1])))
                    end
                end
            end
        end
    end
    return results
end
# Out:
# readingThreadFiles (generic function with 1 method)

# %%
function parse_thread_results(results)
    parsed_results = results |>
                    @groupby(_.threads) |>
                    @map({threads = key(_),
                          mean_estimate = mean(_.full_time),
                          ci_estimate = 1.96 * std(_.full_time)}) |>
                    DataFrame
    
    return parsed_results
end
# Out:
# parse_thread_results (generic function with 1 method)

# %%
function plot_thread_results(x, y, title, yerror = [], min_thread_power = 0, max_thread_power = 16)      
        p = scatter(x,
            y,
            title = title,
            xaxis = :log2,
            xlabel = "Número de Threads",
            xticks = [2 ^ x for x in min_thread_power:max_thread_power],
            yerror = yerror,
            alpha = 0.6,
            legend = :topright)
    
    return p
end
# Out:
# plot_thread_results (generic function with 4 methods)

# %% [markdown]
# ## Análise do Programa Sequencial
#
# Primeiramente, vamos utilizar os resultados obtidos nas execuções do programa sequencial para analisar as diferenças entre as quatro diferentes regiões calculadas e também analisar a influência das operações de IO e de alocação de memória.

# %%
elephant_results = readingSeqFiles("elephant")
elephant_parsed_results = parse_seq_results(elephant_results)

elephant_real_mean = (elephant_parsed_results.mean_full_estimate .- elephant_parsed_results.mean_io_estimate
                     .- elephant_parsed_results.mean_alloc_estimate)

plot_seq_results(elephant_parsed_results.size, elephant_parsed_results.mean_full_estimate, "Elephant Valley",
                    elephant_parsed_results.ci_full_estimate, 4, 13)

scatter!(elephant_parsed_results.size, elephant_real_mean)

# %%
seahorse_results = readingSeqFiles("seahorse")
seahorse_parsed_results = parse_seq_results(seahorse_results)

seahorse_real_mean = (seahorse_parsed_results.mean_full_estimate .- seahorse_parsed_results.mean_io_estimate
                     .- seahorse_parsed_results.mean_alloc_estimate)

plot_seq_results(seahorse_parsed_results.size, seahorse_parsed_results.mean_full_estimate, "Seahorse Valley",
                    seahorse_parsed_results.ci_full_estimate, 4, 13)

scatter!(seahorse_parsed_results.size, seahorse_real_mean)

# %%
triple_spiral_results = readingSeqFiles("triple_spiral")
triple_spiral_parsed_results = parse_seq_results(triple_spiral_results)

triple_spiral_real_mean = (triple_spiral_parsed_results.mean_full_estimate .- triple_spiral_parsed_results.mean_io_estimate
                     .- triple_spiral_parsed_results.mean_alloc_estimate)

plot_seq_results(triple_spiral_parsed_results.size, triple_spiral_parsed_results.mean_full_estimate, "Triple Spiral Valley",
                    triple_spiral_parsed_results.ci_full_estimate, 4, 13)

scatter!(triple_spiral_parsed_results.size, triple_spiral_real_mean)

# %%
full_results = readingSeqFiles("full")
full_parsed_results = parse_seq_results(full_results)

full_real_mean = (full_parsed_results.mean_full_estimate .- full_parsed_results.mean_io_estimate
                     .- full_parsed_results.mean_alloc_estimate)

plot_seq_results(full_parsed_results.size, full_parsed_results.mean_full_estimate, "Full Picture",
                    full_parsed_results.ci_full_estimate, 4, 13)

scatter!(full_parsed_results.size, full_real_mean)

# %% [markdown]
# #### Diferenças entre as Regiões

# %% [markdown]
# #### Análise de I/O e Alocação de Memória

# %% [markdown]
# ## Análise do Programa Paralelizado com Pthreads
#
# Agora, vamos analisar o desempenho do programa paralelizado utilizando a biblioteca Pthreads. Vamos comparar as diferenças para as diferentes regiões, mas também, e principalmente, as diferenças no tempo de execução baseado no número de threads utilizadas. Vamos considerar nas análises também o tamanho da entrada.

# %%
full_results = readingThreadFiles("full", 128, "pth")
full_parsed_results = parse_thread_results(full_results)

plot_thread_results(full_parsed_results.threads, full_parsed_results.mean_estimate, "Full Picture",
                    full_parsed_results.ci_estimate, 0, 5)

# %%
full_results = readingThreadFiles("full", 512, "pth")
full_parsed_results = parse_thread_results(full_results)

plot_thread_results(full_parsed_results.threads, full_parsed_results.mean_estimate, "Full Picture",
                    full_parsed_results.ci_estimate, 0, 5)

# %%
full_results = readingThreadFiles("full", 1024, "pth")
full_parsed_results = parse_thread_results(full_results)

plot_thread_results(full_parsed_results.threads, full_parsed_results.mean_estimate, "Full Picture",
                    full_parsed_results.ci_estimate, 0, 5)

# %%
full_results = readingThreadFiles("full", 2048, "pth")
full_parsed_results = parse_thread_results(full_results)

plot_thread_results(full_parsed_results.threads, full_parsed_results.mean_estimate, "Full Picture",
                    full_parsed_results.ci_estimate, 0, 5)

# %%
full_results = readingThreadFiles("full", 2048, "pth")
full_parsed_results = parse_thread_results(full_results)

plot_thread_results(full_parsed_results.threads, full_parsed_results.mean_estimate, "Full Picture",
                    full_parsed_results.ci_estimate, 0, 5)

# %% [markdown]
# #### Análise das threads

# %% [markdown]
# Análise das regiões

# %% [markdown]
# ## Análise do Programa Paralelizado com OpenMP
#
# Agora, vamos analisar o desempenho do programa paralelizado utilizando a biblioteca Pthreads. Vamos comparar as diferenças para as diferentes regiões, mas também, e principalmente, as diferenças no tempo de execução baseado no número de threads utilizadas. Vamos considerar nas análises também o tamanho da entrada.

# %% [markdown]
# for j in regions
#     for i in 16..8192
#         plot(i)
#         x numero de threads
#         y mean duration

# %% [markdown]
# #### Análise das threads

# %% [markdown]
# Análise das regiões

# %%
using CSV

function save_csv_results(df, filename)
   CSV.write(string(filename, ".csv"), df) 
end

save_csv_results(parsed_results, "results")

# %%
using CSV

function read_csv_results(filename)
    return CSV.read(filename)
end

read_csv_results("results.csv")
